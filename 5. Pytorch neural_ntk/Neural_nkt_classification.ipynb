# %%
import pandas as pd
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

# %%
path='binary_classification_data2.csv'

# %%
data=pd.read_csv(path)
data.head(6)
# Out:
#          X1        X2  label
# 0  0.754246  0.231481      1
# 1 -0.756159  0.153259      1
# 2 -0.815392  0.173282      1
# 3 -0.393731  0.692883      1
# 4  0.442208 -0.896723      0
# 5 -0.479646  0.676435      1

# %%
X = data[['X1', 'X2']].values #combining data
Y = data['label'].values

# %%
## Turn data into tensors
X=torch.tensor(X)
Y=torch.tensor(Y)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2,
                                                    random_state=42)

# %%
#making device agnostic code:
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cpu'

# %%
# Build model with non-linear activation function
from torch import nn
class ModelV2(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer_1 = nn.Linear(in_features=2, out_features=10)
        self.layer_2 = nn.Linear(in_features=10, out_features=10)
        self.layer_3 = nn.Linear(in_features=10, out_features=1)
        self.relu = nn.ReLU() # <- add in ReLU activation function
        # Can also put sigmoid in the model
        # This would mean you don't need to use it on the predictions
        # self.sigmoid = nn.Sigmoid()

    def forward(self, x):
      # Intersperse the ReLU activation function between layers
       return self.layer_3(self.relu(self.layer_2(self.relu(self.layer_1(x)))))

model_2 = ModelV2().to(device)
print(model_2)
# Out:
# ModelV2(
#   (layer_1): Linear(in_features=2, out_features=10, bias=True)
#   (layer_2): Linear(in_features=10, out_features=10, bias=True)
#   (layer_3): Linear(in_features=10, out_features=1, bias=True)
#   (relu): ReLU()
# )

# %% [markdown]
# ![Neural Network](download.png)

# %%
# 1. Setup settings
model = model_2
epochs = 800
train_loss_history = []
test_loss_history = []

# 2. Define Loss and Optimizer
loss_fn = nn.BCEWithLogitsLoss()
optimizer = torch.optim.SGD(params=model.parameters(), lr=0.1)

# %%
# Convert your data to the correct PyTorch data types
X_train = X_train.float()
X_test = X_test.float()
y_train = y_train.float()  # Use .float() for BCEWithLogitsLoss
y_test = y_test.float()

# 3. The Core Training and Testing Loop
for epoch in range(epochs):
    ### Training Mode
    model.train()
    y_logits = model(X_train).squeeze() # Get raw network outputs
    loss = loss_fn(y_logits, y_train)   # Calculate training loss

    optimizer.zero_grad()               # Clear old gradients
    loss.backward()                     # Backpropagation
    optimizer.step()                    # Update model weights


    ### Testing Mode
    model.eval()
    with torch.inference_mode():
        test_logits = model(X_test).squeeze()
        test_loss = loss_fn(test_logits, y_test)
        train_loss_history.append(loss.item())
        test_loss_history.append(test_loss.item())

    # Print progress every 10 epochs
    if epoch % 10 == 0 or epoch == epochs - 1:
        print(f"Epoch: {epoch} | Train Loss: {loss:.5f} | Test Loss: {test_loss:.5f}")
# Out:
# Epoch: 0 | Train Loss: 0.71432 | Test Loss: 0.71458
# Epoch: 10 | Train Loss: 0.70325 | Test Loss: 0.70417
# Epoch: 20 | Train Loss: 0.69832 | Test Loss: 0.69947
# Epoch: 30 | Train Loss: 0.69593 | Test Loss: 0.69717
# Epoch: 40 | Train Loss: 0.69471 | Test Loss: 0.69599
# Epoch: 50 | Train Loss: 0.69405 | Test Loss: 0.69534
# Epoch: 60 | Train Loss: 0.69365 | Test Loss: 0.69495
# Epoch: 70 | Train Loss: 0.69339 | Test Loss: 0.69469
# Epoch: 80 | Train Loss: 0.69320 | Test Loss: 0.69450
# Epoch: 90 | Train Loss: 0.69303 | Test Loss: 0.69435
# Epoch: 100 | Train Loss: 0.69288 | Test Loss: 0.69422
# Epoch: 110 | Train Loss: 0.69274 | Test Loss: 0.69410
# Epoch: 120 | Train Loss: 0.69259 | Test Loss: 0.69399
# Epoch: 130 | Train Loss: 0.69243 | Test Loss: 0.69388
# Epoch: 140 | Train Loss: 0.69225 | Test Loss: 0.69374
# Epoch: 150 | Train Loss: 0.69210 | Test Loss: 0.69363
# Epoch: 160 | Train Loss: 0.69197 | Test Loss: 0.69355
# Epoch: 170 | Train Loss: 0.69185 | Test Loss: 0.69348
# Epoch: 180 | Train Loss: 0.69172 | Test Loss: 0.69340
# Epoch: 190 | Train Loss: 0.69160 | Test Loss: 0.69334
# Epoch: 200 | Train Loss: 0.69147 | Test Loss: 0.69327
# Epoch: 210 | Train Loss: 0.69134 | Test Loss: 0.69320
# Epoch: 220 | Train Loss: 0.69121 | Test Loss: 0.69313
# Epoch: 230 | Train Loss: 0.69107 | Test Loss: 0.69306
# Epoch: 240 | Train Loss: 0.69094 | Test Loss: 0.69299
# Epoch: 250 | Train Loss: 0.69080 | Test Loss: 0.69292
# Epoch: 710 | Train Loss: 0.67351 | Test Loss: 0.68049
# Epoch: 720 | Train Loss: 0.67259 | Test Loss: 0.67975
# Epoch: 730 | Train Loss: 0.67160 | Test Loss: 0.67893
# Epoch: 740 | Train Loss: 0.67056 | Test Loss: 0.67805
# Epoch: 750 | Train Loss: 0.66947 | Test Loss: 0.67711
# Epoch: 760 | Train Loss: 0.66832 | Test Loss: 0.67611
# Epoch: 770 | Train Loss: 0.66710 | Test Loss: 0.67506
# Epoch: 780 | Train Loss: 0.66581 | Test Loss: 0.67398
# Epoch: 790 | Train Loss: 0.66442 | Test Loss: 0.67284
# Epoch: 799 | Train Loss: 0.66304 | Test Loss: 0.67172

# %%
import matplotlib.pyplot as plt

# Since these are now standard Python lists of numbers over time,
# len() will work perfectly to map out your epochs!
epoch_count = list(range(len(train_loss_history)))

plt.figure(figsize=(10, 7))
plt.plot(epoch_count, train_loss_history, label="Train loss")
plt.plot(epoch_count, test_loss_history, label="Test loss")
plt.title("Training and test loss curves for first ntk")
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.legend()
plt.show()

# %%
# 4. Helper function to plot decision boundaries (Built right here!)
def local_plot_boundary(model, X, y):
    # Create a grid of points covering the data area
    x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
    y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100), np.linspace(y_min, y_max, 100))

    # Predict the class for every point on the grid
    grid_points = torch.from_numpy(np.c_[xx.ravel(), yy.ravel()]).float()
    model.eval()
    with torch.inference_mode():
        preds = torch.sigmoid(model(grid_points)).round().numpy()

    # Plot the boundary colors and the actual data points
    plt.contourf(xx, yy, preds.reshape(xx.shape), alpha=0.7, cmap=plt.cm.RdYlBu)
    plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.RdYlBu, edgecolors="k")

# %%
# 5. Plot the Results
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.title("Train")
local_plot_boundary(model, X_train, y_train)

plt.subplot(1, 2, 2)
plt.title("Test")
local_plot_boundary(model, X_test, y_test)

plt.show()

# %% [markdown]
# Model is underfitting so we need to add more layers or neurons

# %%
import torch.nn as nn

class ModelV2(nn.Module):
    def __init__(self):
        super().__init__()
        # Increasing out_features gives the model more "neurons" to think with
        self.layer_1 = nn.Linear(in_features=2, out_features=16) # Boosted to 16
        self.layer_2 = nn.Linear(in_features=16, out_features=16) # Boosted to 16
        self.layer_3 = nn.Linear(in_features=16, out_features=1)
        self.relu = nn.ReLU()

    def forward(self, x):
        # Pass data through layers and activate with ReLU to allow curves
        x = self.relu(self.layer_1(x))
        x = self.relu(self.layer_2(x))
        x = self.layer_3(x) # Output raw logits directly
        return x

# Instantiate the new model
model_3 = ModelV2()

# %%
# 1. Setup settings
model = model_3
epochs = 800
train_loss_history = []
test_loss_history = []

# 2. Define Loss and Optimizer
loss_fn = nn.BCEWithLogitsLoss()
optimizer = torch.optim.SGD(params=model.parameters(), lr=0.1)

# %%
# Convert your data to the correct PyTorch data types
X_train = X_train.float()
X_test = X_test.float()
y_train = y_train.float()  # Use .float() for BCEWithLogitsLoss
y_test = y_test.float()

# 3. The Core Training and Testing Loop
for epoch in range(epochs):
    ### Training Mode
    model.train()
    y_logits = model(X_train).squeeze() # Get raw network outputs
    loss = loss_fn(y_logits, y_train)   # Calculate training loss

    optimizer.zero_grad()               # Clear old gradients
    loss.backward()                     # Backpropagation
    optimizer.step()                    # Update model weights
    train_loss_history.append(loss.item())
    test_loss_history.append(test_loss.item())

    ### Testing Mode
    model.eval()
    with torch.inference_mode():
        test_logits = model(X_test).squeeze()
        test_loss = loss_fn(test_logits, y_test)

    # Print progress every 10 epochs
    if epoch % 10 == 0 or epoch == epochs - 1:
        print(f"Epoch: {epoch} | Train Loss: {loss:.5f} | Test Loss: {test_loss:.5f}")
# Out:
# Epoch: 0 |
# Epoch: 480 | Train Loss: 0.66781 | Test Loss: 0.67990
# Epoch: 490 | Train Loss: 0.66684 | Test Loss: 0.67920
# Epoch: 500 | Train Loss: 0.66584 | Test Loss: 0.67847
# Epoch: 510 | Train Loss: 0.66481 | Test Loss: 0.67768
# Epoch: 520 | Train Loss: 0.66374 | Test Loss: 0.67685
# Epoch: 530 | Train Loss: 0.66261 | Test Loss: 0.67595
# Epoch: 540 | Train Loss: 0.66143 | Test Loss: 0.67500
# Epoch: 550 | Train Loss: 0.66020 | Test Loss: 0.67398
# Epoch: 560 | Train Loss: 0.65893 | Test Loss: 0.67292
# Epoch: 570 | Train Loss: 0.65761 | Test Loss: 0.67180
# Epoch: 580 | Train Loss: 0.65625 | Test Loss: 0.67058
# Epoch: 590 | Train Loss: 0.65482 | Test Loss: 0.66928
# Epoch: 600 | Train Loss: 0.65332 | Test Loss: 0.66788
# Epoch: 610 | Train Loss: 0.65173 | Test Loss: 0.66636
# Epoch: 620 | Train Loss: 0.65007 | Test Loss: 0.66476
# Epoch: 630 | Train Loss: 0.64833 | Test Loss: 0.66309
# Epoch: 640 | Train Loss: 0.64652 | Test Loss: 0.66138
# Epoch: 650 | Train Loss: 0.64463 | Test Loss: 0.65959
# Epoch: 660 | Train Loss: 0.64263 | Test Loss: 0.65768
# Epoch: 670 | Train Loss: 0.64051 | Test Loss: 0.65563
# Epoch: 680 | Train Loss: 0.63825 | Test Loss: 0.65341
# Epoch: 690 | Train Loss: 0.63588 | Test Loss: 0.65107
# Epoch: 700 | Train Loss: 0.63336 | Test Loss: 0.64856
# Epoch: 710 | Train Loss: 0.63067 | Test Loss: 0.64588
# Epoch: 720 | Train Loss: 0.62781 | Test Loss: 0.64305
# Epoch: 730 | Train Loss: 0.62477 | Test Loss: 0.64006
# Epoch: 740 | Train Loss: 0.62150 | Test Loss: 0.63680
# Epoch: 750 | Train Loss: 0.61797 | Test Loss: 0.63329
# Epoch: 760 | Train Loss: 0.61421 | Test Loss: 0.62963
# Epoch: 770 | Train Loss: 0.61018 | Test Loss: 0.62581
# Epoch: 780 | Train Loss: 0.60583 | Test Loss: 0.62175
# Epoch: 790 | Train Loss: 0.60113 | Test Loss: 0.61731
# Epoch: 799 | Train Loss: 0.59661 | Test Loss: 0.61301

# %%
import matplotlib.pyplot as plt

# Since these are now standard Python lists of numbers over time,
# len() will work perfectly to map out your epochs!
epoch_count = list(range(len(train_loss_history)))

plt.figure(figsize=(10, 7))
plt.plot(epoch_count, train_loss_history, label="Train loss")
plt.plot(epoch_count, test_loss_history, label="Test loss")
plt.title("Training and test loss curves for the second neural network")
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.legend()
plt.show()

# %%
# 4. Helper function to plot decision boundaries (Built right here!)
def local_plot_boundary(model, X, y):
    # Create a grid of points covering the data area
    x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
    y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100), np.linspace(y_min, y_max, 100))

    # Predict the class for every point on the grid
    grid_points = torch.from_numpy(np.c_[xx.ravel(), yy.ravel()]).float()
    model.eval()
    with torch.inference_mode():
        preds = torch.sigmoid(model(grid_points)).round().numpy()

    # Plot the boundary colors and the actual data points
    plt.contourf(xx, yy, preds.reshape(xx.shape), alpha=0.7, cmap=plt.cm.RdYlBu)
    plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.RdYlBu, edgecolors="k")

# %%
# 5. Plot the Results
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.title("Train")
local_plot_boundary(model, X_train, y_train)

plt.subplot(1, 2, 2)
plt.title("Test")
local_plot_boundary(model, X_test, y_test)

plt.show()
